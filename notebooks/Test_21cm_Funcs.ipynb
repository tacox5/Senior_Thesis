# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy import units as u

# %%
def T_sys(z):
    """
    Computes the system temperature 
    
    Args:
        z: (float)
            redshift of the observation
            
    Returns:
        
    """
    nu = 1420. * u.MHz / (z + 1)
    return (100. + 120. * (nu / (150. * u.MHz)) ** -2.55) * u.K

# %%
nu = np.linspace(50, 250, 100)
zs = 1420. / nu - 1
T = T_sys(zs)

# %%
plt.figure(figsize = (10,6))
plt.plot(nu, T)
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.plot(nu, zs)
plt.show()
